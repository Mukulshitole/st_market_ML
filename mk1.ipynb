# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apar = yf.download("APARINDS.NS", start ="2010-01-01",end ="2024-02-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple = yf.download("AAPL", start ="2010-01-01",end ="2024-01-10")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.470738
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.481929
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.378824
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.367033
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.409361
# ...                ...         ...         ...         ...         ...
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.678177
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.949097
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.323517
# 2024-01-09  183.919998  185.149994  182.729996  185.139999  184.904053
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
a = [1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
Apar
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04   173.949997   173.949997   168.649994   169.500000   129.980728
# 2010-01-05   173.000000   179.800003   170.500000   174.800003   134.045029
# 2010-01-06   176.000000   179.949997   175.100006   176.300003   135.195312
# 2010-01-07   179.899994   191.800003   178.000000   181.500000   139.182922
# 2010-01-08   183.000000   195.000000   182.500000   191.949997   147.196472
# ...                 ...          ...          ...          ...          ...
# 2024-01-24  5370.000000  5650.000000  5330.149902  5628.899902  5628.899902
# 2024-01-25  5648.950195  5670.000000  5431.000000  5466.049805  5466.049805
# 2024-01-29  5469.899902  5788.000000  5467.049805  5752.549805  5752.549805
# 2024-01-30  5758.899902  6388.000000  5740.500000  6068.750000  6068.750000
# 2024-01-31  6068.750000  6450.000000  5990.299805  6321.299805  6321.299805
#
#             Volume
# Date
# 2010-01-04    8292
# ...

# %%
ticker= ["APARINDS.NS","POLYCAB.NS","KEI.NS"]

# %%
Stocks = yf.download(ticker, start ="2010-01-01",end ="2024-02-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
Stocks
# Out:
#               Adj Close                                  Close               \
#             APARINDS.NS       KEI.NS   POLYCAB.NS  APARINDS.NS       KEI.NS
# Date
# 2010-01-04   129.980728    30.571629          NaN   169.500000    33.299999
# 2010-01-05   134.045029    32.958607          NaN   174.800003    35.900002
# 2010-01-06   135.195312    34.197990          NaN   176.300003    37.250000
# 2010-01-07   139.182922    35.712795          NaN   181.500000    38.900002
# 2010-01-08   147.196472    36.263641          NaN   191.949997    39.500000
# ...                 ...          ...          ...          ...          ...
# 2024-01-24  5628.899902  3314.750000  4361.700195  5628.899902  3314.750000
# 2024-01-25  5466.049805  3183.000000  4343.850098  5466.049805  3183.000000
# 2024-01-29  5752.549805  3193.149902  4346.200195  5752.549805  3193.149902
# 2024-01-30  6068.750000  3061.949951  4314.000000  6068.750000  3061.949951
# ...

# %%
Stocks.head()
# Out:
#              Adj Close                             Close             \
#            APARINDS.NS     KEI.NS POLYCAB.NS APARINDS.NS     KEI.NS
# Date
# 2010-01-04  129.980728  30.571629        NaN  169.500000  33.299999
# 2010-01-05  134.045029  32.958607        NaN  174.800003  35.900002
# 2010-01-06  135.195312  34.197990        NaN  176.300003  37.250000
# 2010-01-07  139.182922  35.712795        NaN  181.500000  38.900002
# 2010-01-08  147.196472  36.263641        NaN  191.949997  39.500000
#
#                              High                               Low  \
#            POLYCAB.NS APARINDS.NS     KEI.NS POLYCAB.NS APARINDS.NS
# Date
# 2010-01-04        NaN  173.949997  33.799999        NaN  168.649994
# 2010-01-05        NaN  179.800003  36.549999        NaN  170.500000
# 2010-01-06        NaN  179.949997  38.500000        NaN  175.100006
# 2010-01-07        NaN  191.800003  40.299999        NaN  178.000000
# ...

# %%
Stocks.tail()
# Out:
#               Adj Close                                  Close               \
#             APARINDS.NS       KEI.NS   POLYCAB.NS  APARINDS.NS       KEI.NS
# Date
# 2024-01-24  5628.899902  3314.750000  4361.700195  5628.899902  3314.750000
# 2024-01-25  5466.049805  3183.000000  4343.850098  5466.049805  3183.000000
# 2024-01-29  5752.549805  3193.149902  4346.200195  5752.549805  3193.149902
# 2024-01-30  6068.750000  3061.949951  4314.000000  6068.750000  3061.949951
# 2024-01-31  6321.299805  3193.100098  4343.149902  6321.299805  3193.100098
#
#                                High                                    Low  \
#              POLYCAB.NS APARINDS.NS       KEI.NS   POLYCAB.NS  APARINDS.NS
# Date
# 2024-01-24  4361.700195      5650.0  3360.000000  4400.000000  5330.149902
# 2024-01-25  4343.850098      5670.0  3318.000000  4455.000000  5431.000000
# 2024-01-29  4346.200195      5788.0  3221.750000  4408.500000  5467.049805
# ...

# %%
Stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3475 entries, 2010-01-04 to 2024-01-31
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (Adj Close, APARINDS.NS)  3475 non-null   float64
#  1   (Adj Close, KEI.NS)       3475 non-null   float64
#  2   (Adj Close, POLYCAB.NS)   1185 non-null   float64
#  3   (Close, APARINDS.NS)      3475 non-null   float64
#  4   (Close, KEI.NS)           3475 non-null   float64
#  5   (Close, POLYCAB.NS)       1185 non-null   float64
#  6   (High, APARINDS.NS)       3475 non-null   float64
#  7   (High, KEI.NS)            3475 non-null   float64
#  8   (High, POLYCAB.NS)        1185 non-null   float64
#  9   (Low, APARINDS.NS)        3475 non-null   float64
#  10  (Low, KEI.NS)             3475 non-null   float64
#  11  (Low, POLYCAB.NS)         1185 non-null   float64
#  12  (Open, APARINDS.NS)       3475 non-null   float64
# ...

# %%
Stocks.to_csv("Stocksmk.csv")

# %%
Stocks = pd.read_csv("Stocksmk.csv")

# %%
Stocks
# Out:
#       Unnamed: 0           Adj Close        Adj Close.1       Adj Close.2  \
# 0            NaN         APARINDS.NS             KEI.NS        POLYCAB.NS
# 1           Date                 NaN                NaN               NaN
# 2     2010-01-04  129.98072814941406  30.57162857055664               NaN
# 3     2010-01-05  134.04502868652344   32.9586067199707               NaN
# 4     2010-01-06         135.1953125  34.19799041748047               NaN
# ...          ...                 ...                ...               ...
# 3472  2024-01-24    5628.89990234375            3314.75   4361.7001953125
# 3473  2024-01-25     5466.0498046875             3183.0  4343.85009765625
# 3474  2024-01-29     5752.5498046875   3193.14990234375   4346.2001953125
# 3475  2024-01-30             6068.75  3061.949951171875            4314.0
# 3476  2024-01-31     6321.2998046875   3193.10009765625  4343.14990234375
#
#                   Close             Close.1           Close.2  \
# ...

# %%
Stocks = pd.read_csv("Stocksmk.csv",header=[0,1])
Stocks
# Out:
#      Unnamed: 0_level_0    Adj Close                                  Close  \
#      Unnamed: 0_level_1  APARINDS.NS       KEI.NS   POLYCAB.NS  APARINDS.NS
# 0                  Date          NaN          NaN          NaN          NaN
# 1            2010-01-04   129.980728    30.571629          NaN   169.500000
# 2            2010-01-05   134.045029    32.958607          NaN   174.800003
# 3            2010-01-06   135.195312    34.197990          NaN   176.300003
# 4            2010-01-07   139.182922    35.712795          NaN   181.500000
# ...                 ...          ...          ...          ...          ...
# 3471         2024-01-24  5628.899902  3314.750000  4361.700195  5628.899902
# 3472         2024-01-25  5466.049805  3183.000000  4343.850098  5466.049805
# 3473         2024-01-29  5752.549805  3193.149902  4346.200195  5752.549805
# 3474         2024-01-30  6068.750000  3061.949951  4314.000000  6068.750000
# ...

# %%
Stocks = pd.read_csv("Stocksmk.csv",header=[0,1],index_col=[0])
Stocks
# Out:
#               Adj Close                                  Close               \
#             APARINDS.NS       KEI.NS   POLYCAB.NS  APARINDS.NS       KEI.NS
# Date
# 2010-01-04   129.980728    30.571629          NaN   169.500000    33.299999
# 2010-01-05   134.045029    32.958607          NaN   174.800003    35.900002
# 2010-01-06   135.195312    34.197990          NaN   176.300003    37.250000
# 2010-01-07   139.182922    35.712795          NaN   181.500000    38.900002
# 2010-01-08   147.196472    36.263641          NaN   191.949997    39.500000
# ...                 ...          ...          ...          ...          ...
# 2024-01-24  5628.899902  3314.750000  4361.700195  5628.899902  3314.750000
# 2024-01-25  5466.049805  3183.000000  4343.850098  5466.049805  3183.000000
# 2024-01-29  5752.549805  3193.149902  4346.200195  5752.549805  3193.149902
# 2024-01-30  6068.750000  3061.949951  4314.000000  6068.750000  3061.949951
# ...

# %%
Stocks = pd.read_csv("Stocksmk.csv",header=[0,1],index_col=[0],parse_dates=[0])
Stocks
# Out:
#               Adj Close                                  Close               \
#             APARINDS.NS       KEI.NS   POLYCAB.NS  APARINDS.NS       KEI.NS
# Date
# 2010-01-04   129.980728    30.571629          NaN   169.500000    33.299999
# 2010-01-05   134.045029    32.958607          NaN   174.800003    35.900002
# 2010-01-06   135.195312    34.197990          NaN   176.300003    37.250000
# 2010-01-07   139.182922    35.712795          NaN   181.500000    38.900002
# 2010-01-08   147.196472    36.263641          NaN   191.949997    39.500000
# ...                 ...          ...          ...          ...          ...
# 2024-01-24  5628.899902  3314.750000  4361.700195  5628.899902  3314.750000
# 2024-01-25  5466.049805  3183.000000  4343.850098  5466.049805  3183.000000
# 2024-01-29  5752.549805  3193.149902  4346.200195  5752.549805  3193.149902
# 2024-01-30  6068.750000  3061.949951  4314.000000  6068.750000  3061.949951
# ...

# %%
Stocks.columns
# Out:
# MultiIndex([('Adj Close', 'APARINDS.NS'),
#             ('Adj Close',      'KEI.NS'),
#             ('Adj Close',  'POLYCAB.NS'),
#             (    'Close', 'APARINDS.NS'),
#             (    'Close',      'KEI.NS'),
#             (    'Close',  'POLYCAB.NS'),
#             (     'High', 'APARINDS.NS'),
#             (     'High',      'KEI.NS'),
#             (     'High',  'POLYCAB.NS'),
#             (      'Low', 'APARINDS.NS'),
#             (      'Low',      'KEI.NS'),
#             (      'Low',  'POLYCAB.NS'),
#             (     'Open', 'APARINDS.NS'),
#             (     'Open',      'KEI.NS'),
#             (     'Open',  'POLYCAB.NS'),
#             (   'Volume', 'APARINDS.NS'),
#             (   'Volume',      'KEI.NS'),
#             (   'Volume',  'POLYCAB.NS')],
#            )

# %%
#convert mult index to one tuple
Stocks.columns=Stocks.columns.to_flat_index()

# %%
Stocks.columns
# Out:
# Index([('Adj Close', 'APARINDS.NS'),      ('Adj Close', 'KEI.NS'),
#         ('Adj Close', 'POLYCAB.NS'),     ('Close', 'APARINDS.NS'),
#                 ('Close', 'KEI.NS'),      ('Close', 'POLYCAB.NS'),
#             ('High', 'APARINDS.NS'),           ('High', 'KEI.NS'),
#              ('High', 'POLYCAB.NS'),       ('Low', 'APARINDS.NS'),
#                   ('Low', 'KEI.NS'),        ('Low', 'POLYCAB.NS'),
#             ('Open', 'APARINDS.NS'),           ('Open', 'KEI.NS'),
#              ('Open', 'POLYCAB.NS'),    ('Volume', 'APARINDS.NS'),
#                ('Volume', 'KEI.NS'),     ('Volume', 'POLYCAB.NS')],
#       dtype='object')

# %%
Stocks
# Out:
#             (Adj Close, APARINDS.NS)  (Adj Close, KEI.NS)  \
# Date
# 2010-01-04                129.980728            30.571629
# 2010-01-05                134.045029            32.958607
# 2010-01-06                135.195312            34.197990
# 2010-01-07                139.182922            35.712795
# 2010-01-08                147.196472            36.263641
# ...                              ...                  ...
# 2024-01-24               5628.899902          3314.750000
# 2024-01-25               5466.049805          3183.000000
# 2024-01-29               5752.549805          3193.149902
# 2024-01-30               6068.750000          3061.949951
# 2024-01-31               6321.299805          3193.100098
#
#             (Adj Close, POLYCAB.NS)  (Close, APARINDS.NS)  (Close, KEI.NS)  \
# Date
# 2010-01-04                      NaN            169.500000        33.299999
# 2010-01-05                      NaN            174.800003        35.900002
# ...

# %%
Stocks.columns=pd.MultiIndex.from_tuples(Stocks.columns)
Stocks
# Out:
#               Adj Close                                  Close               \
#             APARINDS.NS       KEI.NS   POLYCAB.NS  APARINDS.NS       KEI.NS
# Date
# 2010-01-04   129.980728    30.571629          NaN   169.500000    33.299999
# 2010-01-05   134.045029    32.958607          NaN   174.800003    35.900002
# 2010-01-06   135.195312    34.197990          NaN   176.300003    37.250000
# 2010-01-07   139.182922    35.712795          NaN   181.500000    38.900002
# 2010-01-08   147.196472    36.263641          NaN   191.949997    39.500000
# ...                 ...          ...          ...          ...          ...
# 2024-01-24  5628.899902  3314.750000  4361.700195  5628.899902  3314.750000
# 2024-01-25  5466.049805  3183.000000  4343.850098  5466.049805  3183.000000
# 2024-01-29  5752.549805  3193.149902  4346.200195  5752.549805  3193.149902
# 2024-01-30  6068.750000  3061.949951  4314.000000  6068.750000  3061.949951
# ...

# %%
Stocks.columns
# Out:
# MultiIndex([('Adj Close', 'APARINDS.NS'),
#             ('Adj Close',      'KEI.NS'),
#             ('Adj Close',  'POLYCAB.NS'),
#             (    'Close', 'APARINDS.NS'),
#             (    'Close',      'KEI.NS'),
#             (    'Close',  'POLYCAB.NS'),
#             (     'High', 'APARINDS.NS'),
#             (     'High',      'KEI.NS'),
#             (     'High',  'POLYCAB.NS'),
#             (      'Low', 'APARINDS.NS'),
#             (      'Low',      'KEI.NS'),
#             (      'Low',  'POLYCAB.NS'),
#             (     'Open', 'APARINDS.NS'),
#             (     'Open',      'KEI.NS'),
#             (     'Open',  'POLYCAB.NS'),
#             (   'Volume', 'APARINDS.NS'),
#             (   'Volume',      'KEI.NS'),
#             (   'Volume',  'POLYCAB.NS')],
#            )

# %%
Stocks.describe()
# Out:
#          Adj Close                                  Close               \
#        APARINDS.NS       KEI.NS   POLYCAB.NS  APARINDS.NS       KEI.NS
# count  3475.000000  3475.000000  1185.000000  3475.000000  3475.000000
# mean    669.714859   443.267170  2096.690493   705.325380   446.059813
# std    1027.184312   657.296961  1356.579439  1022.098783   657.065720
# min      73.677910     6.663660   522.754639    84.300003     6.900000
# 25%     170.858513    27.679718   900.025940   216.025002    29.725000
# 50%     396.106384   135.561127  2113.449951   438.450012   138.399994
# 75%     640.702881   473.497910  2648.119629   673.799988   480.025009
# max    6321.299805  3380.250000  5691.950195  6321.299805  3380.250000
#
#                            High                                    Low  \
#         POLYCAB.NS  APARINDS.NS       KEI.NS   POLYCAB.NS  APARINDS.NS
# count  1185.000000  3475.000000  3475.000000  1185.000000  3475.000000
# ...

# %%
Close=Stocks.loc[:,"Close"].copy()

# %%
Close
# Out:
#             APARINDS.NS       KEI.NS   POLYCAB.NS
# Date
# 2010-01-04   169.500000    33.299999          NaN
# 2010-01-05   174.800003    35.900002          NaN
# 2010-01-06   176.300003    37.250000          NaN
# 2010-01-07   181.500000    38.900002          NaN
# 2010-01-08   191.949997    39.500000          NaN
# ...                 ...          ...          ...
# 2024-01-24  5628.899902  3314.750000  4361.700195
# 2024-01-25  5466.049805  3183.000000  4343.850098
# 2024-01-29  5752.549805  3193.149902  4346.200195
# 2024-01-30  6068.750000  3061.949951  4314.000000
# 2024-01-31  6321.299805  3193.100098  4343.149902
#
# [3475 rows x 3 columns]

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Seaborn Style Example')
plt.show()

# %%
Close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
Close.iloc[0,0]
# Out:
# 169.5

# %%
Close.iloc[0]
# Out:
# APARINDS.NS    169.500000
# KEI.NS          33.299999
# POLYCAB.NS            NaN
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
Close.div(Close.iloc[0]).mul(100)
# Out:
#             APARINDS.NS       KEI.NS  POLYCAB.NS
# Date
# 2010-01-04   100.000000   100.000000         NaN
# 2010-01-05   103.126845   107.807815         NaN
# 2010-01-06   104.011801   111.861864         NaN
# 2010-01-07   107.079646   116.816824         NaN
# 2010-01-08   113.244836   118.618621         NaN
# ...                 ...          ...         ...
# 2024-01-24  3320.884898  9954.204432         NaN
# 2024-01-25  3224.808144  9558.558778         NaN
# 2024-01-29  3393.834693  9589.038965         NaN
# 2024-01-30  3580.383481  9195.045109         NaN
# 2024-01-31  3729.380416  9588.889402         NaN
#
# [3475 rows x 3 columns]

# %%
Close
# Out:
#             APARINDS.NS       KEI.NS   POLYCAB.NS
# Date
# 2010-01-04   169.500000    33.299999          NaN
# 2010-01-05   174.800003    35.900002          NaN
# 2010-01-06   176.300003    37.250000          NaN
# 2010-01-07   181.500000    38.900002          NaN
# 2010-01-08   191.949997    39.500000          NaN
# ...                 ...          ...          ...
# 2024-01-24  5628.899902  3314.750000  4361.700195
# 2024-01-25  5466.049805  3183.000000  4343.850098
# 2024-01-29  5752.549805  3193.149902  4346.200195
# 2024-01-30  6068.750000  3061.949951  4314.000000
# 2024-01-31  6321.299805  3193.100098  4343.149902
#
# [3475 rows x 3 columns]

# %%
Close["APARINDS.NS"]
# Out:
# Date
# 2010-01-04     169.500000
# 2010-01-05     174.800003
# 2010-01-06     176.300003
# 2010-01-07     181.500000
# 2010-01-08     191.949997
#                  ...
# 2024-01-24    5628.899902
# 2024-01-25    5466.049805
# 2024-01-29    5752.549805
# 2024-01-30    6068.750000
# 2024-01-31    6321.299805
# Name: APARINDS.NS, Length: 3475, dtype: float64

# %%
normclose=Close.div(Close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(20,15),fontsize=20)
# Out:
# <Axes: xlabel='Date'>

# %%
Apar=Close["APARINDS.NS"].copy().to_frame()

# %%
Apar
# Out:
#             APARINDS.NS
# Date
# 2010-01-04   169.500000
# 2010-01-05   174.800003
# 2010-01-06   176.300003
# 2010-01-07   181.500000
# 2010-01-08   191.949997
# ...                 ...
# 2024-01-24  5628.899902
# 2024-01-25  5466.049805
# 2024-01-29  5752.549805
# 2024-01-30  6068.750000
# 2024-01-31  6321.299805
#
# [3475 rows x 1 columns]

# %%
Apar.shift(periods=1)
# Out:
#             APARINDS.NS
# Date
# 2010-01-04          NaN
# 2010-01-05   169.500000
# 2010-01-06   174.800003
# 2010-01-07   176.300003
# 2010-01-08   181.500000
# ...                 ...
# 2024-01-24  5351.700195
# 2024-01-25  5628.899902
# 2024-01-29  5466.049805
# 2024-01-30  5752.549805
# 2024-01-31  6068.750000
#
# [3475 rows x 1 columns]

# %%
Apar["lag1"]=Apar.shift(periods=1)

# %%
Apar
# Out:
#             APARINDS.NS         lag1
# Date
# 2010-01-04   169.500000          NaN
# 2010-01-05   174.800003   169.500000
# 2010-01-06   176.300003   174.800003
# 2010-01-07   181.500000   176.300003
# 2010-01-08   191.949997   181.500000
# ...                 ...          ...
# 2024-01-24  5628.899902  5351.700195
# 2024-01-25  5466.049805  5628.899902
# 2024-01-29  5752.549805  5466.049805
# 2024-01-30  6068.750000  5752.549805
# 2024-01-31  6321.299805  6068.750000
#
# [3475 rows x 2 columns]

# %%
Apar['Diff'] = Apar['APARINDS.NS'] - Apar['APARINDS.NS'].shift(1)

# %%
Apar
# Out:
#             APARINDS.NS         lag1        Diff
# Date
# 2010-01-04   169.500000          NaN         NaN
# 2010-01-05   174.800003   169.500000    5.300003
# 2010-01-06   176.300003   174.800003    1.500000
# 2010-01-07   181.500000   176.300003    5.199997
# 2010-01-08   191.949997   181.500000   10.449997
# ...                 ...          ...         ...
# 2024-01-24  5628.899902  5351.700195  277.199707
# 2024-01-25  5466.049805  5628.899902 -162.850098
# 2024-01-29  5752.549805  5466.049805  286.500000
# 2024-01-30  6068.750000  5752.549805  316.200195
# 2024-01-31  6321.299805  6068.750000  252.549805
#
# [3475 rows x 3 columns]

# %%
Apar["% Change"]=Apar["APARINDS.NS"].div(Apar.lag1).sub(1).mul(100)

# %%
Apar
# Out:
#             APARINDS.NS         lag1        Diff  % Change
# Date
# 2010-01-04   169.500000          NaN         NaN       NaN
# 2010-01-05   174.800003   169.500000    5.300003  3.126845
# 2010-01-06   176.300003   174.800003    1.500000  0.858124
# 2010-01-07   181.500000   176.300003    5.199997  2.949516
# 2010-01-08   191.949997   181.500000   10.449997  5.757574
# ...                 ...          ...         ...       ...
# 2024-01-24  5628.899902  5351.700195  277.199707  5.179657
# 2024-01-25  5466.049805  5628.899902 -162.850098 -2.893107
# 2024-01-29  5752.549805  5466.049805  286.500000  5.241445
# 2024-01-30  6068.750000  5752.549805  316.200195  5.496696
# 2024-01-31  6321.299805  6068.750000  252.549805  4.161480
#
# [3475 rows x 4 columns]

# %%
Apar["diff2"]=Apar["APARINDS.NS"].diff(periods=1)
Apar
# Out:
#             APARINDS.NS         lag1        Diff  % Change       diff2
# Date
# 2010-01-04   169.500000          NaN         NaN       NaN         NaN
# 2010-01-05   174.800003   169.500000    5.300003  3.126845    5.300003
# 2010-01-06   176.300003   174.800003    1.500000  0.858124    1.500000
# 2010-01-07   181.500000   176.300003    5.199997  2.949516    5.199997
# 2010-01-08   191.949997   181.500000   10.449997  5.757574   10.449997
# ...                 ...          ...         ...       ...         ...
# 2024-01-24  5628.899902  5351.700195  277.199707  5.179657  277.199707
# 2024-01-25  5466.049805  5628.899902 -162.850098 -2.893107 -162.850098
# 2024-01-29  5752.549805  5466.049805  286.500000  5.241445  286.500000
# 2024-01-30  6068.750000  5752.549805  316.200195  5.496696  316.200195
# 2024-01-31  6321.299805  6068.750000  252.549805  4.161480  252.549805
#
# [3475 rows x 5 columns]

# %%
Apar["% Change 2"]=Apar["APARINDS.NS"].pct_change(periods=1).mul(100)

# %%
Apar
# Out:
#             APARINDS.NS         lag1        Diff  % Change       diff2  \
# Date
# 2010-01-04   169.500000          NaN         NaN       NaN         NaN
# 2010-01-05   174.800003   169.500000    5.300003  3.126845    5.300003
# 2010-01-06   176.300003   174.800003    1.500000  0.858124    1.500000
# 2010-01-07   181.500000   176.300003    5.199997  2.949516    5.199997
# 2010-01-08   191.949997   181.500000   10.449997  5.757574   10.449997
# ...                 ...          ...         ...       ...         ...
# 2024-01-24  5628.899902  5351.700195  277.199707  5.179657  277.199707
# 2024-01-25  5466.049805  5628.899902 -162.850098 -2.893107 -162.850098
# 2024-01-29  5752.549805  5466.049805  286.500000  5.241445  286.500000
# 2024-01-30  6068.750000  5752.549805  316.200195  5.496696  316.200195
# 2024-01-31  6321.299805  6068.750000  252.549805  4.161480  252.549805
#
#             % Change 2
# Date
# 2010-01-04         NaN
# 2010-01-05    3.126845
# 2010-01-06    0.858124
# ...

# %%
del Apar["% Change"]

# %%
Apar
# Out:
#             APARINDS.NS         lag1        Diff       diff2  % Change 2
# Date
# 2010-01-04   169.500000          NaN         NaN         NaN         NaN
# 2010-01-05   174.800003   169.500000    5.300003    5.300003    3.126845
# 2010-01-06   176.300003   174.800003    1.500000    1.500000    0.858124
# 2010-01-07   181.500000   176.300003    5.199997    5.199997    2.949516
# 2010-01-08   191.949997   181.500000   10.449997   10.449997    5.757574
# ...                 ...          ...         ...         ...         ...
# 2024-01-24  5628.899902  5351.700195  277.199707  277.199707    5.179657
# 2024-01-25  5466.049805  5628.899902 -162.850098 -162.850098   -2.893107
# 2024-01-29  5752.549805  5466.049805  286.500000  286.500000    5.241445
# 2024-01-30  6068.750000  5752.549805  316.200195  316.200195    5.496696
# 2024-01-31  6321.299805  6068.750000  252.549805  252.549805    4.161480
#
# [3475 rows x 5 columns]

# %%
Apar.rename(columns ={'% Change 2':'Change'}, inplace = True)

# %%
Apar
# Out:
#             APARINDS.NS         lag1        Diff       diff2    Change
# Date
# 2010-01-04   169.500000          NaN         NaN         NaN       NaN
# 2010-01-05   174.800003   169.500000    5.300003    5.300003  3.126845
# 2010-01-06   176.300003   174.800003    1.500000    1.500000  0.858124
# 2010-01-07   181.500000   176.300003    5.199997    5.199997  2.949516
# 2010-01-08   191.949997   181.500000   10.449997   10.449997  5.757574
# ...                 ...          ...         ...         ...       ...
# 2024-01-24  5628.899902  5351.700195  277.199707  277.199707  5.179657
# 2024-01-25  5466.049805  5628.899902 -162.850098 -162.850098 -2.893107
# 2024-01-29  5752.549805  5466.049805  286.500000  286.500000  5.241445
# 2024-01-30  6068.750000  5752.549805  316.200195  316.200195  5.496696
# 2024-01-31  6321.299805  6068.750000  252.549805  252.549805  4.161480
#
# [3475 rows x 5 columns]

# %%
Apar["APARINDS.NS"].resample("M").last()
# Out:
# Date
# 2010-01-31     170.399994
# 2010-02-28     165.699997
# 2010-03-31     197.399994
# 2010-04-30     231.350006
# 2010-05-31     235.199997
#                  ...
# 2023-09-30    5477.549805
# 2023-10-31    5179.450195
# 2023-11-30    5581.399902
# 2023-12-31    6053.399902
# 2024-01-31    6321.299805
# Freq: M, Name: APARINDS.NS, Length: 169, dtype: float64

# %%
Apar["APARINDS.NS"].resample("BM").last()
# Out:
# Date
# 2010-01-29     170.399994
# 2010-02-26     165.699997
# 2010-03-31     197.399994
# 2010-04-30     231.350006
# 2010-05-31     235.199997
#                  ...
# 2023-09-29    5477.549805
# 2023-10-31    5179.450195
# 2023-11-30    5581.399902
# 2023-12-29    6053.399902
# 2024-01-31    6321.299805
# Freq: BM, Name: APARINDS.NS, Length: 169, dtype: float64

# %%
Apar["APARINDS.NS"].resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26    -2.758214
# 2010-03-31    19.130958
# 2010-04-30    17.198588
# 2010-05-31     1.664141
#                 ...
# 2023-09-29     9.366163
# 2023-10-31    -5.442207
# 2023-11-30     7.760471
# 2023-12-29     8.456660
# 2024-01-31     4.425611
# Freq: BM, Name: APARINDS.NS, Length: 169, dtype: float64

# %%
Apar
# Out:
#             APARINDS.NS         lag1        Diff       diff2    Change
# Date
# 2010-01-04   169.500000          NaN         NaN         NaN       NaN
# 2010-01-05   174.800003   169.500000    5.300003    5.300003  3.126845
# 2010-01-06   176.300003   174.800003    1.500000    1.500000  0.858124
# 2010-01-07   181.500000   176.300003    5.199997    5.199997  2.949516
# 2010-01-08   191.949997   181.500000   10.449997   10.449997  5.757574
# ...                 ...          ...         ...         ...       ...
# 2024-01-24  5628.899902  5351.700195  277.199707  277.199707  5.179657
# 2024-01-25  5466.049805  5628.899902 -162.850098 -162.850098 -2.893107
# 2024-01-29  5752.549805  5466.049805  286.500000  286.500000  5.241445
# 2024-01-30  6068.750000  5752.549805  316.200195  316.200195  5.496696
# 2024-01-31  6321.299805  6068.750000  252.549805  252.549805  4.161480
#
# [3475 rows x 5 columns]

# %%
del Apar["Change"]

# %%
Apar
# Out:
#             APARINDS.NS         lag1        Diff       diff2
# Date
# 2010-01-04   169.500000          NaN         NaN         NaN
# 2010-01-05   174.800003   169.500000    5.300003    5.300003
# 2010-01-06   176.300003   174.800003    1.500000    1.500000
# 2010-01-07   181.500000   176.300003    5.199997    5.199997
# 2010-01-08   191.949997   181.500000   10.449997   10.449997
# ...                 ...          ...         ...         ...
# 2024-01-24  5628.899902  5351.700195  277.199707  277.199707
# 2024-01-25  5466.049805  5628.899902 -162.850098 -162.850098
# 2024-01-29  5752.549805  5466.049805  286.500000  286.500000
# 2024-01-30  6068.750000  5752.549805  316.200195  316.200195
# 2024-01-31  6321.299805  6068.750000  252.549805  252.549805
#
# [3475 rows x 4 columns]

# %%
ret = Apar.pct_change().dropna()
